# %%
from __future__ import division
import numpy as np
import sys

# %%
#Universal Constants
c = 3e8
G = 6.67e-11
Msolar = 2e30
AU = 1.49e11 #meters

# %%
def sma(M,f):
    #Total mass, orbital frequency
    return (G*M/(2*np.pi*f)**2)**(1/3)

def ang_mom(m1,m2,a):
    M = m1+m2
    return m1*m2 * np.sqrt(G*a/M)

def derivs(y):
    e = y[0]
    gamma = y[1]
    
    de = 5*K*e*(1-e**2)*(1-np.cos(I)**2)*np.sin(2*gamma)/J1    
    
    dg_part1 = 2*(1-e**2) - 5*(1-e**2 - np.cos(I)**2)*np.sin(gamma)**2
    dg_part2 = (1 - e**2 + 5*e**2 * np.cos(gamma)**2)*np.cos(I)
    dg = 2*K*(dg_part1/J1 + dg_part2/J2)
    
    if Kozai == 1:
        return np.array((de,dg))
    else:
        return np.array((0.0,0.0)) #turn off derivative changes due to Kozai

# %%
#Inner binary parameters
m0 = 30*Msolar
m1 = 30*Msolar
f1 = 1e-3 #orbital frequency
e1 = 0.5 #eccentricity
eps1 = 1-e1**2
a1 = sma(m0+m1,f1)#semi major axis via K3
J1 = ang_mom(m0,m1,a1)
beta = 100
box = f**2*(m0+m1)*eps1/(beta**2 * G * a1**3)
print ('Semi major axis of inner binary = ', a1/AU, ' AU')

#Outer binary parameters
m2 = 1*Msolar
e2 = 0.7
eps2 = 1-e2**2

a2 = (m2**2/(box*eps2**3))**(1/6) #sets the 



J2 = ang_mom(m0+m1,m2,a2)
print ('Semi major axis of outer binary = ', a2/AU, ' AU')

#Shared
I = 45 * np.pi/180.0 #Inclination
gamma = np.pi/4
K = 3*G*m0*m1*m2*a1**2 / (8*(m0+m1) * a2**3*(1-e2**2)**(3/2))


tKL = np.sqrt(G*m2**2*a1**3 / ((m0+m1)*a2**6 * eps1*eps2**3))


print ('tKL = ', tKL**(-1), 'seconds')
print ('t inner orbit', f1**(-1), 'seconds')
print ('Ratio = ', f1/tKL)


Kozai = 1
# Out:
# Semi major axis of inner binary =  0.003942722210092745  AU
# Semi major axis of outer binary =  0.012671958833357767  AU
# tKL =  99999.99999999967 seconds
# t inner orbit 1000.0 seconds
# Ratio =  99.99999999999967

# %%
#Now do a basic numerical integration using RK4

h = 1 #Stepsize . seconds

Tfinal = 5  #years
Tf = 5*365*24*3600 #seconds

nsteps = int(Tf / h)


out = np.zeros((nsteps,3)) #t,e,gamma
yn = np.array((e,gamma))


t = 0
counter = 0
while t < Tf:

    
    k1 = derivs(yn)
    k2 = h * derivs(yn + k1/2)
    k3 = h * derivs(yn + k2/2)
    k4 = h * derivs(yn + k3)
    ynew = yn + (k1 + 2*k2 + 2*k3 + k4)/6
    yn = ynew
    
    t = t + h
    
    out[counter,0] = t
    out[counter,1:2] = yn 
    counter = counter + 1

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

x = np.arange(nsteps)
plot_e = out[:,0]
plot_g = out[:,1]

fig = plt.figure(figsize=(10,10))
ax1 = plt.subplot2grid((2,1), (0,0)) 
ax2 = plt.subplot2grid((2,1), (1,0), sharex=ax1) 
ax1.plot(x, plot_e)
ax1.scatter(x, plot_e)
ax2.plot(x, np.sin(2*plot_g))
plt.savefig('Figs/e_KZ='+str(Kozai)+'.png', dpi = 300)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-261-c4dede70013d> in <module>
#      11 ax2 = plt.subplot2grid((2,1), (1,0), sharex=ax1)
#      12 ax1.plot(x, plot_e)
# ---> 13 ax1.scatter(x, plot_e)
#      14 ax2.plot(x, np.sin(2*plot_g))
#      15 plt.savefig('Figs/e_KZ='+str(Kozai)+'.png', dpi = 300)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4324                 self.set_ymargin(0.05)
#    4325
# -> 4326         self.add_collection(collection)
#    4327         self.autoscale_view()
#    4328
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in add_collection(self, collection, autolim)
#    1859
#    1860         if autolim:
# -> 1861             self.update_datalim(collection.get_datalim(self.transData))
#    1862
#    1863         self.stale = True
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in get_datalim(self, transData)
#     203             result = mpath.get_path_collection_extents(
#     204                 transform.frozen(), paths, self.get_transforms(),
# --> 205                 offsets, transOffset.frozen())
#     206             result = result.inverse_transformed(transData)
#     207         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/path.py in get_path_collection_extents(master_transform, paths, transforms, offsets, offset_transform)
#     988     return Bbox.from_extents(*_path.get_path_collection_extents(
#     989         master_transform, paths, np.atleast_3d(transforms),
# --> 990         offsets, offset_transform))
#     991
#     992
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/path.py in vertices(self)
#     201         self._has_nonfinite = not np.isfinite(self._vertices).all()
#     202
# --> 203     @property
#     204     def vertices(self):
#     205         """
#
# KeyboardInterrupt:
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.

# %%
from scipy import special as sp

#Calculate the ABC for the quadrupole derivative


e_var = plot_e
g_var = plot_g
t = np.arange(len(e_var))
MA = 2*np.pi*f1*t #mean anomaly ?
mu = m0*m1/(m0+m1) #reduced mass of inner binary
AA = (2*np.pi*f1*(m0+m1))**(2/3) * mu
iota = 20 * np.pi/180  #angle of L vector w.r.t observer LOS 



nsum = 2

hGW = np.zeros((nsteps, 2))
for n in np.arange(1,nsum+1):

    J_2 = sp.jv(n-2,n*e_var)
    J_1 = sp.jv(n-1,n*e_var) 
    Jn = sp.jv(n,n*e_var) 
    J1 = sp.jv(n+1,n*e_var)
    J2 = sp.jv(n+2,n*e_var)
    
    an = -n*AA*(J_2 - 2*e_var*J_1 + 2*Jn/n + 2*e_var*J1 - J2)*np.cos(n*MA)
    bn = -n*AA*np.sqrt((1-e_var**2)) * (J_2 - 2*Jn + J2)*np.sin(n*MA)
    cn = 2*AA*Jn*np.cos(n*MA)
    
    
    hplus = -(1+np.cos(iota)) * (an*np.cos(2*g_var) - bn*np.sin(2*g_var)) + (1-np.cos(iota)**2)*cn
    hcross = 2*np.cos(iota)*(bn*np.cos(2*g_var) + an*np.sin(2*gamma))
    
    hGW[:,0] = hGW[:,0] + hplus
    hGW[:,1] = hGW[:,1] + hcross

# %%
x = np.arange(nsteps)
hplus = hGW[:,0]
hcross = hGW[:,1]

fig = plt.figure(figsize=(10,10))
ax1 = plt.subplot2grid((2,1), (0,0)) 
ax2 = plt.subplot2grid((2,1), (1,0), sharex=ax1) 
ax1.plot(x, hplus)
ax2.plot(x, hcross)
plt.savefig('Figs/GW_KZ='+str(Kozai)+'.png', dpi = 300)
